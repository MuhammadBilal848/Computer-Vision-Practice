# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# * Shifting this window will cause the change in pixels.

# %% [markdown]
# ![image.png](attachment:image.png)
# * Since window in this picture is outside (flat region) because there wont be any change if we move in any direction using window.

# %% [markdown]
# ![image.png](attachment:image.png)
# * Means if we keep moving in the same direction using window we wont experience any significant change(we will experience change but not that much).

# %% [markdown]
# ![image.png](attachment:image.png)
# * If we keep moving in a direction and experience a major change then we can say that we have detected an edge.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

# %%
fc = cv.imread('../Data/flat_chessboard.png')
fc = cv.cvtColor(fc,cv.COLOR_BGR2RGB)
plt.imshow(fc)

# %%
gfc = cv.imread('../Data/flat_chessboard.png')
gfc = cv.cvtColor(gfc,cv.COLOR_BGR2GRAY)
plt.imshow(gfc,cmap = 'gray')

# %%
rc = cv.imread('../Data/real_chessboard.jpg')
rc = cv.cvtColor(rc,cv.COLOR_BGR2RGB)
plt.imshow(rc)

# %%
grc = cv.imread('../Data/real_chessboard.jpg')
grc = cv.cvtColor(grc,cv.COLOR_BGR2GRAY)
plt.imshow(grc,cmap = 'gray')

# %% [markdown]
# # cv::cornerHarris
# $$cv.cornerHarris(	src, blockSize, ksize, k[, dst[, borderType]]	) ->dst$$
# * **src** : Input single-channel 8-bit or floating-point image.
# * **dst** : Image to store the Harris detector responses. It has the type CV_32FC1 and the same size as src .
# * **blockSize** : Neighborhood size (see the details on cornerEigenValsAndVecs ).
# * **ksize** : Aperture parameter for the Sobel operator or kernel size for sobel operator.
# * **k** : Harris detector free parameter. See the formula above.
# * **borderType** : Pixel extrapolation method. See BorderTypes. BORDER_WRAP is not supported.
#
# * The function runs the Harris corner detector on the image. Similarly to cornerMinEigenVal and cornerEigenValsAndVecs , for each pixel (x,y) it calculates a 2×2 gradient covariance matrix M(x,y) over a blockSize×blockSize neighborhood. Then, it computes the following characteristic:
# ![image.png](attachment:image.png)

# %% [markdown]
# ### <center> Flat Chess <center/>

# %% [markdown]
# ## First we will convert the values to float as we will be needing the float values for corner detection

# %%
gfc = np.float32(gfc)
plt.imshow(gfc,cmap = 'gray')

# %%
corhas = cv.cornerHarris(gfc,blockSize = 3,ksize = 3,k = 0.04)

# %% [markdown]
# * As we can see the function has detected the edges
# * In order to get desired one can experiment with the values.

# %%
plt.figure(figsize=(10,10))
plt.imshow(corhas,cmap='gray')

# %% [markdown]
# * We will dilate the **corhas** to make white pixels more visible

# %%
corhas = cv.dilate(corhas,None)
plt.figure(figsize=(10,10))
plt.imshow(corhas,cmap='gray')

# %% [markdown]
# * Now we will map the values on the original flat chess image.
# * In the code below we are using boolean mapping to color map values where **corhas** is having values greater than 1 percent of **corhas** max value.
# * 0.01 is just a number for mapping or you can say a standard formula used for mapping values.

# %%
fc[corhas>0.01*corhas.max()] = [0,0,255]

# %%
plt.figure(figsize=(10,10))
plt.imshow(fc)

# %% [markdown]
# ### <center> Real Chess <center/>

# %%
grc = np.float32(grc)
plt.imshow(grc,cmap = 'gray')

# %%
corhas2 = cv.cornerHarris(grc,4,3,0.02)
plt.figure(figsize=(10,10))
plt.imshow(corhas2,cmap = 'gray')

# %%
corhas2 = cv.dilate(corhas2,None)
plt.figure(figsize=(10,10))
plt.imshow(corhas2,cmap = 'gray')

# %%
rc[corhas2>0.01*corhas2.max()] = [255,0,0]

# %%
# we can see that the algorithm detected major corners even the edge corners but also the corners on pieces.
plt.figure(figsize=(10,10))
plt.imshow(rc)

# %%
plt.imshow(fc)

# %% [markdown]
# # cv::goodFeaturesToTrack
# $$cv.goodFeaturesToTrack(image, maxCorners, qualityLevel, minDistance[, corners[, mask[, blockSize[, useHarrisDetector[, k]]]]]) ->corners$$
# $$cv.goodFeaturesToTrack(image, maxCorners, qualityLevel, minDistance, mask, blockSize, gradientSize[, corners[, useHarrisDetector[, k]]]) ->corners$$
# * **image** : Input 8-bit or floating-point 32-bit, single-channel image.
# * **corners** : Output vector of detected corners.
# * **maxCorners** : Maximum number of corners to return. If there are more corners than are found, the strongest of them is returned. maxCorners <= 0 implies that no limit on the maximum is set and all detected corners are returned.
# * **qualityLevel** : Parameter characterizing the minimal accepted quality of image corners. The parameter value is multiplied by the best corner quality measure, which is the minimal eigenvalue (see cornerMinEigenVal ) or the Harris function response (see cornerHarris ). The corners with the quality measure less than the product are rejected. For example, if the best corner has the quality measure = 1500, and the qualityLevel=0.01 , then all the corners with the quality measure less than 15 are rejected.
# * **minDistance** : Minimum possible Euclidean distance between the returned corners.
# * **mask** : Optional region of interest. If the image is not empty (it needs to have the type CV_8UC1 and the same size as image ), it specifies the region in which the corners are detected.
# * **blockSize** : Size of an average block for computing a derivative covariation matrix over each pixel neighborhood. See cornerEigenValsAndVecs .
# * **useHarrisDetector** : Parameter indicating whether to use a Harris detector (see cornerHarris) or cornerMinEigenVal.
# * **k** : Free parameter of the Harris detector.

# %%
fc = cv.imread('../Data/flat_chessboard.png')
fc = cv.cvtColor(fc,cv.COLOR_BGR2RGB)
gfc = cv.imread('../Data/flat_chessboard.png')
gfc = cv.cvtColor(gfc,cv.COLOR_BGR2GRAY)
rc = cv.imread('../Data/real_chessboard.jpg')
rc = cv.cvtColor(rc,cv.COLOR_BGR2RGB)
grc = cv.imread('../Data/real_chessboard.jpg')
grc = cv.cvtColor(grc,cv.COLOR_BGR2GRAY)

# %% [markdown]
# ### <center> Flat Chess <center/>

# %%
corners = cv.goodFeaturesToTrack(gfc,15,0.01,8)
# this returns the corner coordinates in float dtype

# %%
corners = np.int0(corners)

# %%
corners
# Out:
# array([[[308, 308]],
#
#        [[264, 308]],
#
#        [[220, 308]],
#
#        [[176, 308]],
#
#        [[132, 308]],
#
#        [[ 88, 308]],
#
#        [[ 44, 308]],
#
#        [[308, 264]],
#
#        [[264, 264]],
#
#        [[220, 264]],
#
#        [[176, 264]],
#
#        [[132, 264]],
#
#        [[ 88, 264]],
#
#        [[ 44, 264]],
#
#        [[308, 220]]], dtype=int64)

# %% [markdown]
# * Unlike harris algorithm , shi Tomashi doesn't automatically highlight the points on an image.
# * We need to circle the corners.
# * We will use ravel function of numpy to flatten the array.

# %%
# that's how ravel works
corners.ravel()
# Out:
# array([308, 308, 264, 308, 220, 308, 176, 308, 132, 308,  88, 308,  44,
#        308, 308, 264, 264, 264, 220, 264, 176, 264, 132, 264,  88, 264,
#         44, 264, 308, 220], dtype=int64)

# %%
for cor in corners:
    x,y = cor.ravel()
    cv.circle(fc,(x,y),5,(0,0,255),-1)

# %%
plt.figure(figsize=(10,10))
plt.imshow(fc)

# %% [markdown]
# ### <center> Real Chess <center/>

# %%
rcorners = cv.goodFeaturesToTrack(grc,80,0.01,10)

# %%
rcorners = np.int0(rcorners)

# %%
for rcor in rcorners:
    x,y = rcor.ravel()
    cv.circle(rc,(x,y),5,(255,0,0),-1)

# %%
plt.figure(figsize=(10,10))
plt.imshow(rc)
