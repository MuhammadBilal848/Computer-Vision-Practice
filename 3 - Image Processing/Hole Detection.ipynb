# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
import numpy as np
import cv2

def RandomPatternGenerator():
    width, height = 500, 500
    pattern = np.random.randint(0, 256, (height, width, 3), dtype=np.uint8)
    plt.imshow(pattern,cmap = 'gray')
RandomPatternGenerator()

# %%
img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/Opencv/b hole.jpg')
plt.imshow(img)

# %%
img_thresholded = cv2.inRange(img, (60, 60, 60), (140, 140, 140))
plt.imshow(img_thresholded,cmap = 'gray')

# %%
kernel = np.ones((10,10),np.uint8)
opening = cv2.morphologyEx(img_thresholded, cv2.MORPH_OPEN, kernel)
plt.imshow(opening,cmap = 'gray')

# %%
contours, hierarchy = cv2.findContours(opening.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)
print(len(contours))

i = 0
n_radius = []
for contour in contours:
    i += 1
    (x,y),radius = cv2.minEnclosingCircle(contour)
    center = (int(x),int(y))
    radius = int(radius)
    n_radius.append(radius)
    cv2.circle(img,center,radius,(0,255,0),1)
    # labelling the circles around the centers, in no particular order.
    position = (center[0] - 10, center[1] + 10)
    text_color = (0, 0, 255)
    cv2.putText(img, str(i), position, cv2.FONT_HERSHEY_SIMPLEX, 1, text_color, 3)
# Out:
# 6

# %%
plt.imshow(img,)`

# %%
def AOC(radius):
  return (math.pi * ((radius)**2))

# %%
for a in n_radius:
  print(AOC(a))
# Out:
# 2123.7166338267
# 1520.53084433746
# 2290.221044466959
# 2123.7166338267
# 2642.079421669016
# 2290.221044466959
